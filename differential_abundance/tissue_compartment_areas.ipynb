# %%
import numpy as np
import pandas as pd
import geopandas as gpd

import anndata as ad
import scanpy as sc

import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rcParams
import matplotlib.colors as clr

import scvi
import squidpy as sq
import cellcharter as cc
import gc

# %%
sc.settings.n_jobs = -1

# %%
import torch
torch.set_float32_matmul_precision('high')
torch.cuda.is_available()
# Out:
# True

# %%
from lightning.pytorch import seed_everything
seed_everything(12345)
# Out:
# Seed set to 12345
# 12345

# %%
import shapely as sp 
import geopandas as gpd
import libpysal as lps 
import esda
import alphashape as ash

# %%
def get_boundary(coords):
    x = coords.get_coordinates().to_numpy()
    poly = lps.cg.alpha_shape_auto(x, step=1)
    return poly

# %%
adata = sc.read_h5ad("../../data/merfish/BAYSOR/seurat_objects/ns-atlas.merfish_baysor.scanvi_integrated.cellcharter.anndata.annotated.h5ad")

# %%
adata.obs.columns
# Out:
# Index(['EntityID', 'fov', 'volume', 'center_x', 'center_y', 'min_x', 'min_y',
#        'max_x', 'max_y', 'anisotropy',
#        ...
#        'donor_age', 'race_ethnicity', 'DV200', 'RIN', 'preservation_type',
#        'collection_type', 'component_id', 'sample_compartment',
#        'tissue_compartment', 'compartment.short'],
#       dtype='object', length=108)

# %%
del adata.obs['tissue_compartment']
del adata.obs['sample_compartment']
del adata.obs['compartment.short']

# %%
tissue_compartments = pd.read_csv("../../data/merfish/BAYSOR/metadata/tissue_compartment_annotations.csv", index_col=0)
# Out:
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\103280593.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   tissue_compartments = pd.read_csv("../../data/merfish/BAYSOR/metadata/tissue_compartment_annotations.csv", index_col=0)

# %%
tissue_compartments.index = tissue_compartments['cell_barcode'].values.astype(str).tolist()

# %%
tissue_compartments.head()
# Out:
#                             cell_barcode  \
# 1577244300000000000  1577244300000000000
# 1577244300000000001  1577244300000000001
# 1577244300000000002  1577244300000000002
# 1577244300000000003  1577244300000000003
# 1577244300000000006  1577244300000000006
#
#                                                        cell_id  \
# 1577244300000000000  D151_SKIN_NS_S04_R01_C1577244300000000000
# 1577244300000000001  D151_SKIN_NS_S04_R01_C1577244300000000001
# 1577244300000000002  D151_SKIN_NS_S04_R01_C1577244300000000002
# 1577244300000000003  D151_SKIN_NS_S04_R01_C1577244300000000003
# 1577244300000000006  D151_SKIN_NS_S04_R01_C1577244300000000006
#
#                            sample_barcode        sample_compartment  \
# 1577244300000000000  D151_SKIN_NS_S04_R01  D151_SKIN_NS_S04_R01_DER
# 1577244300000000001  D151_SKIN_NS_S04_R01  D151_SKIN_NS_S04_R01_DER
# 1577244300000000002  D151_SKIN_NS_S04_R01  D151_SKIN_NS_S04_R01_DER
# 1577244300000000003  D151_SKIN_NS_S04_R01  D151_SKIN_NS_S04_R01_DER
# 1577244300000000006  D151_SKIN_NS_S04_R01  D151_SKIN_NS_S04_R01_DER
#
#                     tissue_compartment compartment.short
# 1577244300000000000             dermis               DER
# 1577244300000000001             dermis               DER
# 1577244300000000002             dermis               DER
# 1577244300000000003             dermis               DER
# 1577244300000000006             dermis               DER

# %%
tissue_compartments = tissue_compartments.loc[adata.obs_names.values.astype(str).tolist(), ['sample_compartment', 'tissue_compartment', "compartment.short"]].copy()

# %%
adata.obs.index = adata.obs_names.values.astype(str).tolist()

# %%
adata.obs = pd.concat([adata.obs, tissue_compartments], axis=1).copy()

# %%
adata.write_h5ad("../../data/merfish/BAYSOR/seurat_objects/ns-atlas.merfish_baysor.scanvi_integrated.cellcharter.anndata.annotated.h5ad", compression='gzip')

# %%
adata = adata[adata.obs['compartment.short'] != 'OUT'].copy()

# %%
adata.obs.head(10)
# Out:
#                                 EntityID  fov       volume      center_x  \
# 1577244300000000000  1577244300000000000  NaN   413.582367  10833.988067
# 1577244300000000001  1577244300000000001  NaN   954.476268  11088.754365
# 1577244300000000002  1577244300000000002  NaN  2314.160266   9533.604246
# 1577244300000000003  1577244300000000003  NaN  1377.588139  10330.515975
# 1577244300000000006  1577244300000000006  NaN   364.332251  11125.854334
# 1577244300000000008  1577244300000000008  NaN  1137.968435  10640.326353
# 1577244300000000013  1577244300000000013  NaN   471.085336  11066.605192
# 1577244300000000014  1577244300000000014  NaN   965.433572  10854.263308
# 1577244300000000015  1577244300000000015  NaN   514.916523   9348.450583
# 1577244300000000017  1577244300000000017  NaN  1179.214414   8472.042450
#
#                         center_y         min_x        min_y         max_x  \
# 1577244300000000000  5659.833278  10830.405562  5656.014926  10838.326891
# 1577244300000000001  5967.087526  11081.775322  5960.465239  11095.173641
# 1577244300000000002  6785.310602   9526.056136  6778.549632   9543.619093
# 1577244300000000003  5700.319847  10320.137869  5693.969074  10343.894569
# 1577244300000000006  6012.214286  11122.113357  6009.566081  11131.581724
# 1577244300000000008  7268.846994  10634.916613  7262.627689  10647.572479
# 1577244300000000013  5821.276310  11061.106763  5816.906358  11072.093556
# 1577244300000000014  5504.434883  10848.463487  5499.716736  10859.962040
# 1577244300000000015  5482.567898   9344.775658  5477.369742   9351.470938
# 1577244300000000017  5949.888550   8467.573480  5941.958979   8477.315849
#
#                            max_y  anisotropy  ...  donor_age  race_ethnicity  \
# 1577244300000000000  5662.925291    1.535899  ...       36.0             NaN
# 1577244300000000001  5971.335980    1.820862  ...       36.0             NaN
# 1577244300000000002  6794.195938    1.315076  ...       36.0             NaN
# 1577244300000000003  5705.211938    3.583034  ...       36.0             NaN
# 1577244300000000006  6014.614107    1.857338  ...       36.0             NaN
# 1577244300000000008  7274.467481    1.099862  ...       36.0             NaN
# 1577244300000000013  5825.109851    1.461268  ...       36.0             NaN
# 1577244300000000014  5509.464750    1.076560  ...       36.0             NaN
# 1577244300000000015  5487.585487    1.468110  ...       36.0             NaN
# 1577244300000000017  5958.837520    1.936929  ...       36.0             NaN
#
#                      DV200 RIN  preservation_type  collection_type  \
# 1577244300000000000   0.52 NaN               FFPE          autopsy
# 1577244300000000001   0.52 NaN               FFPE          autopsy
# 1577244300000000002   0.52 NaN               FFPE          autopsy
# 1577244300000000003   0.52 NaN               FFPE          autopsy
# 1577244300000000006   0.52 NaN               FFPE          autopsy
# 1577244300000000008   0.52 NaN               FFPE          autopsy
# 1577244300000000013   0.52 NaN               FFPE          autopsy
# 1577244300000000014   0.52 NaN               FFPE          autopsy
# 1577244300000000015   0.52 NaN               FFPE          autopsy
# 1577244300000000017   0.52 NaN               FFPE          autopsy
#
#                                       component_id        sample_compartment  \
# 1577244300000000000     D151_SKIN_NS_S04_R01_N6_C0  D151_SKIN_NS_S04_R01_DER
# 1577244300000000001     D151_SKIN_NS_S04_R01_N6_C0  D151_SKIN_NS_S04_R01_DER
# 1577244300000000002   D151_SKIN_NS_S04_R01_N0_C619  D151_SKIN_NS_S04_R01_DER
# 1577244300000000003   D151_SKIN_NS_S04_R01_N1_Cnan  D151_SKIN_NS_S04_R01_DER
# 1577244300000000006     D151_SKIN_NS_S04_R01_N6_C0  D151_SKIN_NS_S04_R01_DER
# 1577244300000000008  D151_SKIN_NS_S04_R01_N2_C2046  D151_SKIN_NS_S04_R01_EPI
# 1577244300000000013     D151_SKIN_NS_S04_R01_N6_C0  D151_SKIN_NS_S04_R01_DER
# 1577244300000000014     D151_SKIN_NS_S04_R01_N6_C0  D151_SKIN_NS_S04_R01_DER
# 1577244300000000015     D151_SKIN_NS_S04_R01_N6_C1  D151_SKIN_NS_S04_R01_DER
# 1577244300000000017  D151_SKIN_NS_S04_R01_N2_C2046  D151_SKIN_NS_S04_R01_EPI
#
#                      tissue_compartment  compartment.short
# 1577244300000000000              dermis                DER
# 1577244300000000001              dermis                DER
# 1577244300000000002              dermis                DER
# 1577244300000000003              dermis                DER
# 1577244300000000006              dermis                DER
# 1577244300000000008           epidermis                EPI
# 1577244300000000013              dermis                DER
# 1577244300000000014              dermis                DER
# 1577244300000000015              dermis                DER
# 1577244300000000017           epidermis                EPI
#
# [10 rows x 108 columns]

# %%
sample_barcodes = adata.obs['sample_barcode'].values.unique().tolist()

# %%
sample_id = "D077_SKIN_NS_S04_R01"

# %%
compartment_info = adata.obs.loc[adata.obs['sample_barcode'] == sample_id, ['sample_barcode', 'anatomic_site', 'sample_compartment', 'tissue_compartment','total_area_mm2', 'compartment.short', 'center_x', 'center_y']].copy()

# %%
compartment_info.head()
# Out:
#                            sample_barcode anatomic_site  \
# 1577590000000000000  D077_SKIN_NS_S04_R01          back
# 1577590000000000001  D077_SKIN_NS_S04_R01          back
# 1577590000000000003  D077_SKIN_NS_S04_R01          back
# 1577590000000000004  D077_SKIN_NS_S04_R01          back
# 1577590000000000005  D077_SKIN_NS_S04_R01          back
#
#                            sample_compartment tissue_compartment  \
# 1577590000000000000  D077_SKIN_NS_S04_R01_DER             dermis
# 1577590000000000001  D077_SKIN_NS_S04_R01_DER             dermis
# 1577590000000000003  D077_SKIN_NS_S04_R01_DER             dermis
# 1577590000000000004  D077_SKIN_NS_S04_R01_DER             dermis
# 1577590000000000005  D077_SKIN_NS_S04_R01_DER             dermis
#
#                      total_area_mm2 compartment.short      center_x  \
# 1577590000000000000        3.554131               DER  14816.996270
# 1577590000000000001        3.554131               DER  14873.503620
# 1577590000000000003        3.554131               DER  15241.864881
# 1577590000000000004        3.554131               DER  14902.575772
# 1577590000000000005        3.554131               DER  14178.356648
#
#                         center_y
# 1577590000000000000  8320.576036
# 1577590000000000001  8526.353086
# 1577590000000000003  8735.600601
# 1577590000000000004  8326.801012
# 1577590000000000005  7250.963825

# %%
sample_barcodes = adata.obs['sample_barcode'].values.unique().tolist()
compartment_list = []
for sample_id in sample_barcodes:
    compartment_info = adata.obs.loc[adata.obs['sample_barcode'] == sample_id, ['sample_barcode', 'anatomic_site', 'sample_compartment', 'tissue_compartment','total_area_mm2', 'compartment.short', 'center_x', 'center_y']].copy()
    compartment_info['cell_centroids'] = gpd.points_from_xy(compartment_info['center_x'], compartment_info['center_y'])
    compartment_info = gpd.GeoDataFrame(compartment_info, geometry='cell_centroids')

    tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
    tissue_areas = tissue_areas[~tissue_areas['cell_centroids'].is_empty].copy()

    compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
    compartment_areas['geometry'] = compartment_areas['cell_centroids'].make_valid()
    compartment_areas['compartment_area_mm2'] = ((compartment_areas['geometry'].area)/1e6)
    compartment_areas.drop(columns=['cell_centroids'], inplace=True)
    compartment_areas['sample_barcode'] = sample_id

    compartment_areas['total_area_mm2'] = np.repeat(np.array((tissue_areas['cell_centroids'].area)/1e6)[0], len(compartment_areas))
    compartment_areas['compartment_proportion'] = (compartment_areas['compartment_area_mm2']/compartment_areas['compartment_area_mm2'].sum())
    compartment_areas['compartment_area_adjusted'] = np.array(compartment_areas['compartment_proportion']) * np.array((tissue_areas['cell_centroids'].area)/1e6)
    compartment_list.append(compartment_areas)

    del compartment_areas
    del tissue_areas
# Out:
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# ...
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_areas = compartment_info.groupby(['sample_barcode'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index()
# C:\Users\Paula\AppData\Local\Temp\ipykernel_20188\1069911100.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   compartment_areas = compartment_info.groupby(['sample_compartment', 'compartment.short'])['cell_centroids'].agg(lambda x: get_boundary(x)).reset_index().dropna()

# %%
compartment_areas = pd.concat(compartment_list, axis=0)

# %%
compartment_areas.head()
# Out:
#             sample_compartment compartment.short  \
# 1020  D151_SKIN_NS_S04_R01_DER               DER
# 1025  D151_SKIN_NS_S04_R01_EPI               EPI
# 1031  D151_SKIN_NS_S04_R01_SUB               SUB
# 1044  D151_SKIN_NS_S06_R01_DER               DER
# 1049  D151_SKIN_NS_S06_R01_EPI               EPI
#
#                                                geometry  compartment_area_mm2  \
# 1020  POLYGON ((9585.983 6881.832, 9635.663 6916.875...              4.620182
# 1025  POLYGON ((10627.184 7267.071, 10640.326 7268.8...              0.208866
# 1031  POLYGON ((9801.201 5189.63, 10085.047 5424.71,...              0.806162
# 1044  POLYGON ((3474.236 6893.318, 3494.278 6884.882...              5.251671
# 1049  POLYGON ((3025.679 7043.073, 3057.933 7032.784...              0.170103
#
#             sample_barcode  total_area_mm2  compartment_proportion  \
# 1020  D151_SKIN_NS_S04_R01        5.955045                0.819878
# 1025  D151_SKIN_NS_S04_R01        5.955045                0.037064
# 1031  D151_SKIN_NS_S04_R01        5.955045                0.143058
# 1044  D151_SKIN_NS_S06_R01        7.179190                0.750619
# 1049  D151_SKIN_NS_S06_R01        7.179190                0.024313
#
#       compartment_area_adjusted
# 1020                   4.882408
# 1025                   0.220720
# 1031                   0.851917
# 1044                   5.388834
# 1049                   0.174546

# %%
compartment_areas.to_csv("../../data/merfish/BAYSOR/metadata/tissue_compartment_areas.csv", index=False)
compartment_areas.to_parquet("../../data/merfish/BAYSOR/metadata/tissue_compartment_areas.parquet", index=False)

# %%
len(np.unique(compartment_areas['sample_barcode'].values.tolist()))
# Out:
# 114
